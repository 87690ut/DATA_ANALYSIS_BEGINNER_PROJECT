# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ### 1. Load & Check Data

# %%
data = pd.read_csv("Pokemon.csv")

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data[data['Legendary']  == True]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='str')

# %% [markdown]
# ### 2. Filtering

# %% [markdown]
# #### a. create new table in which only thoes pokemon which have legendary == true.

# %%
poke_legend = data[data['Legendary'] == True]
poke_legend
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %% [markdown]
# #### b. Find thoes pokemon whoes attak & defense > 100.

# %%
data.query('Attack  > 100 and Defense > 100')
# Out:
#        #                       Name   Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire    Dragon    634   78     130
# 12     9    BlastoiseMega Blastoise    Water       NaN    630   79     103
# 82    76                      Golem     Rock    Ground    495   80     120
# 107   99                    Kingler    Water       NaN    475   55     130
# 120  112                     Rhydon   Ground      Rock    485  105     130
# 137  127          PinsirMega Pinsir      Bug    Flying    600   65     155
# 141  130      GyaradosMega Gyarados    Water      Dark    640   95     155
# 152  141                   Kabutops     Rock     Water    495   60     115
# 224  208        SteelixMega Steelix    Steel    Ground    610   75     125
# 229  212          ScizorMega Scizor      Bug     Steel    600   70     150
# 232  214    HeracrossMega Heracross      Bug  Fighting    600   80     185
# ...

# %% [markdown]
# ## 3. Sorting

# %% [markdown]
# #### Sort the data according to speed.

# %%
data.sort_values(by = 'Speed',ascending = False)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 71    65      AlakazamMega Alakazam  Psychic     NaN    590   55      50
# 429  386         DeoxysAttack Forme  Psychic     NaN    600   50     180
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# ..   ...                        ...      ...     ...    ...  ...     ...
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 495  446                   Munchlax   Normal     NaN    390  135      85
# 230  213                    Shuckle      Bug    Rock    505   20      10
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## 4. Grouping

# %% [markdown]
# #### a. Find the average of Attack according to Type 1.

# %%
data.groupby('Type 1')['Attack'].mean().round().sort_values(ascending = False)
# Out:
# Type 1
# Dragon      112.0
# Fighting     97.0
# Ground       96.0
# Rock         93.0
# Steel        93.0
# Dark         88.0
# Fire         85.0
# Flying       79.0
# Poison       75.0
# Water        74.0
# Ghost        74.0
# Normal       73.0
# Grass        73.0
# Ice          73.0
# Bug          71.0
# Psychic      71.0
# Electric     69.0
# Fairy        62.0
# Name: Attack, dtype: float64

# %%
data[data['Type 1'] == 'Dragon']['Attack'].mean().round()
# Out:
# np.float64(112.0)

# %%
data[data['Type 1'] == 'Fire']['Attack'].mean().round()
# Out:
# np.float64(85.0)
